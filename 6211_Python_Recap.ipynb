# %% [markdown]
# <a href="https://colab.research.google.com/github/hwillif/Google-Colab-Files/blob/main/6211_Python_Recap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# scalar
x = 4
y = 5
print(x,y,x*y)
# Out:
# 4 5 20

# %%
# vector
v1 =[3,4,5]
v2 =["Monday","Tuesday","Wednesday"]
print(v1,v2)
# Out:
# [3, 4, 5] ['Monday', 'Tuesday', 'Wednesday']

# %%
import numpy as np
np.random.rand(4,3)
# Out:
# array([[0.61238304, 0.21423441, 0.23160847],
#        [0.77706788, 0.03507015, 0.33063519],
#        [0.90809965, 0.44327175, 0.95744804],
#        [0.43218035, 0.49944994, 0.42491043]])

# %%
import pandas as pd
mtcars = pd.read_csv("mtcars.csv")
sample = pd.read_csv("sample.csv")

# %%
np.random.randint(10, size = (4,3))
# Out:
# array([[5, 1, 5],
#        [2, 5, 9],
#        [6, 6, 8],
#        [7, 8, 9]])

# %%
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['mtcars.csv']))

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
mtcars.dtypes
# Out:
# Unnamed: 0     object
# mpg           float64
# cyl             int64
# disp          float64
# hp              int64
# drat          float64
# wt            float64
# qsec          float64
# vs              int64
# am              int64
# gear            int64
# carb            int64
# dtype: object

# %%
pd.crosstab(mtcars['cyl'],mtcars['gear'])
# Out:
# gear   3  4  5
# cyl
# 4      1  8  2
# 6      2  4  1
# 8     12  0  2

# %%
import seaborn as sns
sns.set_theme(style='whitegrid')
sns.catplot(data = mtcars, x='cyl', kind='count')

# %%
sns.catplot(datab=mtcars, x='cyl', kind='count', hue='gear')

# %%
sns.histplot(
    data=mtcars
    , x = 'mpg'
    , color = 'blue'
    , binwidth = 3
).set(title='Histogram of variable mpg')
# Out:
# [Text(0.5, 1.0, 'Histogram of variable mpg')]

# %% [markdown]
# sns.scatterplot(
#     data = mtcars
#     , x = 'mpg'
#     , y = 'wt'
#     , hue = 'cyl'
# )
